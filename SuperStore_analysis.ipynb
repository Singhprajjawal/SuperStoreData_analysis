# %% [markdown]
# # Analysis of SuperStoreData

# %%
import pandas as pd

# %%
df= pd.read_csv('SuperStoreOrders.csv')

# %% [markdown]
# ## Head

# %%
df.head(5)
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %% [markdown]
# ## Tail

# %%
df.tail(4)
# Out:
#              order_id  order_date ship_date       ship_mode     customer_name  \
# 51286    MO-2014-2560  31-12-2014  5/1/2015  Standard Class         Liz Preis
# 51287  MX-2014-110527  31-12-2014  2/1/2015    Second Class  Charlotte Melton
# 51288  MX-2014-114783  31-12-2014  6/1/2015  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720  31-12-2014  4/1/2015  Standard Class     Jill Matthias
#
#         segment             state        country  market   region  ...  \
# 51286  Consumer  Souss-Massa-Draâ        Morocco  Africa   Africa  ...
# 51287  Consumer           Managua      Nicaragua   LATAM  Central  ...
# 51288  Consumer         Chihuahua         Mexico   LATAM    North  ...
# 51289  Consumer          Colorado  United States      US     West  ...
#
#               category sub_category                             product_name  \
# 51286  Office Supplies      Binders  Wilson Jones Hole Reinforcements, Clear
# ...

# %% [markdown]
# ### length of Dataset ?

# %%
df.shape
# Out:
# (51290, 21)

# %% [markdown]
# ### Numberof the Columns?

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %% [markdown]
# # Cleaning the Dataset

# %% [markdown]
# ### Droping the unnecessary columns

# %%
df=df.drop('customer_name', axis=1)
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'segment', 'state',
#        'country', 'market', 'region', 'product_id', 'category', 'sub_category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit',
#        'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %% [markdown]
# ## OR

# %%
df=df.drop(['ship_mode','order_priority'], axis=1)
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'segment', 'state', 'country',
#        'market', 'region', 'product_id', 'category', 'sub_category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit',
#        'shipping_cost', 'year'],
#       dtype='object')

# %%
df.shape
# Out:
# (51290, 18)

# %%
# Only Selecting some columns
df[['order_date','order_id','sales','state','country','market']]
# Out:
#        order_date         order_id sales             state        country  \
# 0        1/1/2011     AG-2011-2040   408       Constantine        Algeria
# 1        1/1/2011    IN-2011-47883   120   New South Wales      Australia
# 2        1/1/2011     HU-2011-1220    66          Budapest        Hungary
# 3        1/1/2011  IT-2011-3647632    45         Stockholm         Sweden
# 4        1/1/2011    IN-2011-47883   114   New South Wales      Australia
# ...           ...              ...   ...               ...            ...
# 51285  31-12-2014   CA-2014-115427    14        California  United States
# 51286  31-12-2014     MO-2014-2560     4  Souss-Massa-Draâ        Morocco
# 51287  31-12-2014   MX-2014-110527    26           Managua      Nicaragua
# 51288  31-12-2014   MX-2014-114783     7         Chihuahua         Mexico
# 51289  31-12-2014   CA-2014-156720     3          Colorado  United States
#
#        market
# 0      Africa
# 1        APAC
# 2        EMEA
# 3          EU
# ...

# %% [markdown]
# ### Datatype of Columns?

# %%
df.dtypes
# Out:
# order_id          object
# order_date        object
# ship_date         object
# segment           object
# state             object
# country           object
# market            object
# region            object
# product_id        object
# category          object
# sub_category      object
# product_name      object
# sales             object
# quantity           int64
# discount         float64
# profit           float64
# shipping_cost    float64
# year               int64
# dtype: object

# %% [markdown]
# ### changing the datatype of required columns.

# %%
df['order_date']=pd.to_datetime(df['order_date'])
df['ship_date']=pd.to_datetime(df['ship_date'])
# Out:
# C:\Users\Prajwal Singh\AppData\Roaming\Python\Python310\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Prajwal Singh\AppData\Roaming\Python\Python310\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Prajwal Singh\AppData\Roaming\Python\Python310\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
df.dtypes
# Out:
# order_id                 object
# order_date       datetime64[ns]
# ship_date        datetime64[ns]
# segment                  object
# state                    object
# country                  object
# market                   object
# region                   object
# product_id               object
# category                 object
# sub_category             object
# product_name             object
# sales                    object
# quantity                  int64
# discount                float64
# profit                  float64
# shipping_cost           float64
# year                      int64
# dtype: object

# %% [markdown]
# ### Adding column?

# %%
df['delivery_days']=df['ship_date']-df['order_date']

# %%
df['delivery_days']=pd.to_datetime(df['delivery_days'])
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 df['delivery_days']=pd.to_datetime(df['delivery_days'])
#       2 df.dtypes
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\tools\datetimes.py:1047, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1045             result = arg.tz_localize(tz)
#    1046 elif isinstance(arg, ABCSeries):
# -> 1047     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1048     if not cache_array.empty:
#    1049         result = arg.map(cache_array)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\tools\datetimes.py:197, in _maybe_cache(arg, format, cache, convert_listlike)
#     195 unique_dates = unique(arg)
#     196 if len(unique_dates) < len(arg):
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'segment', 'state', 'country',
#        'market', 'region', 'product_id', 'category', 'sub_category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit',
#        'shipping_cost', 'year', 'delivery_days'],
#       dtype='object')

# %%
df.head(3)
# Out:
#         order_id order_date  ship_date   segment            state    country  \
# 0   AG-2011-2040 2011-01-01 2011-06-01  Consumer      Constantine    Algeria
# 1  IN-2011-47883 2011-01-01 2011-08-01  Consumer  New South Wales  Australia
# 2   HU-2011-1220 2011-01-01 2011-05-01  Consumer         Budapest    Hungary
#
#    market   region        product_id         category sub_category  \
# 0  Africa   Africa  OFF-TEN-10000025  Office Supplies      Storage
# 1    APAC  Oceania   OFF-SU-10000618  Office Supplies     Supplies
# 2    EMEA     EMEA  OFF-TEN-10001585  Office Supplies      Storage
#
#                product_name sales  quantity  discount   profit  shipping_cost  \
# 0       Tenex Lockers, Blue   408         2       0.0  106.140          35.46
# 1  Acme Trimmer, High Speed   120         3       0.1   36.036           9.72
# 2   Tenex Box, Single Width    66         4       0.0   29.640           8.17
#
#    year delivery_days
# 0  2011      151 days
# 1  2011      212 days
# ...

# %%
df[['order_date','ship_date','delivery_days']]
# Out:
#       order_date  ship_date delivery_days
# 0     2011-01-01 2011-06-01      151 days
# 1     2011-01-01 2011-08-01      212 days
# 2     2011-01-01 2011-05-01      120 days
# 3     2011-01-01 2011-05-01      120 days
# 4     2011-01-01 2011-08-01      212 days
# ...          ...        ...           ...
# 51285 2014-12-31 2015-04-01       91 days
# 51286 2014-12-31 2015-05-01      121 days
# 51287 2014-12-31 2015-02-01       32 days
# 51288 2014-12-31 2015-06-01      152 days
# 51289 2014-12-31 2015-04-01       91 days
#
# [51290 rows x 3 columns]

# %% [markdown]
# ### finding nan values in selected columns ?

# %%
df['state'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Total NAN values in dataframe

# %%
df[:].isna().sum()
# Out:
# order_id         0
# order_date       0
# ship_date        0
# segment          0
# state            0
# country          0
# market           0
# region           0
# product_id       0
# category         0
# sub_category     0
# product_name     0
# sales            0
# quantity         0
# discount         0
# profit           0
# shipping_cost    0
# year             0
# delivery_days    0
# dtype: int64

# %%
df.head(3)
# Out:
#         order_id order_date  ship_date   segment            state    country  \
# 0   AG-2011-2040 2011-01-01 2011-06-01  Consumer      Constantine    Algeria
# 1  IN-2011-47883 2011-01-01 2011-08-01  Consumer  New South Wales  Australia
# 2   HU-2011-1220 2011-01-01 2011-05-01  Consumer         Budapest    Hungary
#
#    market   region        product_id         category sub_category  \
# 0  Africa   Africa  OFF-TEN-10000025  Office Supplies      Storage
# 1    APAC  Oceania   OFF-SU-10000618  Office Supplies     Supplies
# 2    EMEA     EMEA  OFF-TEN-10001585  Office Supplies      Storage
#
#                product_name sales  quantity  discount   profit  shipping_cost  \
# 0       Tenex Lockers, Blue   408         2       0.0  106.140          35.46
# 1  Acme Trimmer, High Speed   120         3       0.1   36.036           9.72
# 2   Tenex Box, Single Width    66         4       0.0   29.640           8.17
#
#    year delivery_days
# 0  2011      151 days
# 1  2011      212 days
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of               order_id order_date  ship_date      segment             state  \
# 0         AG-2011-2040 2011-01-01 2011-06-01     Consumer       Constantine
# 1        IN-2011-47883 2011-01-01 2011-08-01     Consumer   New South Wales
# 2         HU-2011-1220 2011-01-01 2011-05-01     Consumer          Budapest
# 3      IT-2011-3647632 2011-01-01 2011-05-01  Home Office         Stockholm
# 4        IN-2011-47883 2011-01-01 2011-08-01     Consumer   New South Wales
# ...                ...        ...        ...          ...               ...
# 51285   CA-2014-115427 2014-12-31 2015-04-01    Corporate        California
# 51286     MO-2014-2560 2014-12-31 2015-05-01     Consumer  Souss-Massa-Draâ
# 51287   MX-2014-110527 2014-12-31 2015-02-01     Consumer           Managua
# 51288   MX-2014-114783 2014-12-31 2015-06-01     Consumer         Chihuahua
# 51289   CA-2014-156720 2014-12-31 2015-04-01     Consumer          Colorado
#
# ...

# %% [markdown]
# ### How many duplicate records are there?

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, ship_date, segment, state, country, market, region, product_id, category, sub_category, product_name, sales, quantity, discount, profit, shipping_cost, year, delivery_days]
# Index: []

# %% [markdown]
# ### Null Values?

# %%
df.isnull().sum()
# Out:
# order_id         0
# order_date       0
# ship_date        0
# segment          0
# state            0
# country          0
# market           0
# region           0
# product_id       0
# category         0
# sub_category     0
# product_name     0
# sales            0
# quantity         0
# discount         0
# profit           0
# shipping_cost    0
# year             0
# delivery_days    0
# dtype: int64

# %%
df.head(2)
# Out:
#         order_id order_date  ship_date   segment            state    country  \
# 0   AG-2011-2040 2011-01-01 2011-06-01  Consumer      Constantine    Algeria
# 1  IN-2011-47883 2011-01-01 2011-08-01  Consumer  New South Wales  Australia
#
#    market   region        product_id         category sub_category  \
# 0  Africa   Africa  OFF-TEN-10000025  Office Supplies      Storage
# 1    APAC  Oceania   OFF-SU-10000618  Office Supplies     Supplies
#
#                product_name sales  quantity  discount   profit  shipping_cost  \
# 0       Tenex Lockers, Blue   408         2       0.0  106.140          35.46
# 1  Acme Trimmer, High Speed   120         3       0.1   36.036           9.72
#
#    year delivery_days
# 0  2011      151 days
# 1  2011      212 days

# %% [markdown]
# ### Number of records where country in 'Algeria'

# %%
df[df['country'].isin(['Algeria'])]['country'].count()
# Out:
# 196

# %% [markdown]
# ### Avarage discount given by Superstore ?

# %%
df['discount'].mean().round(5)
# Out:
# 0.14291

# %% [markdown]
# ### Avarge delivery days

# %%
df['delivery_days'].mean()
# Out:
# Timedelta('5 days 01:53:49.120686293')

# %% [markdown]
# ## (Timedelta('5 days 01:53:49.120686293')) - days required to get better Sales

# %% [markdown]
# ### How many years sales is ?

# %%
df['year'].unique()
# Out:
# array([2011, 2012, 2013, 2014], dtype=int64)

# %% [markdown]
# ### sales in 2013?

# %%
df[df['year']==2013][['sales','year','sub_category','product_name' ]]
# Out:
#        sales  year sub_category                            product_name
# 19960  1,649  2013      Copiers             Canon Copy Machine, Digital
# 19961  1,358  2013    Bookcases        Sauder Floating Shelf Set, Metal
# 19962    729  2013  Accessories         Logitech Memory Card, Erganomic
# 19963  2,190  2013    Bookcases        Dania Library with Doors, Mobile
# 19964  1,362  2013    Bookcases  Sauder Floating Shelf Set, Traditional
# ...      ...   ...          ...                                     ...
# 33754     10  2013  Furnishings                 Eldon Light Bulb, Black
# 33755     17  2013          Art                               Newell 31
# 33756      6  2013      Binders              Cardinal Hold-It CD Pocket
# 33757      6  2013       Labels                               Avery 487
# 33758     13  2013      Binders            Wilson Jones Binder, Economy
#
# [13799 rows x 4 columns]

# %% [markdown]
# ### total quantity of sales in decreasing order

# %%
sorted_year=df.groupby('year').sales.count().sort_values(ascending= False)
sorted_year
# Out:
# year
# 2014    17531
# 2013    13799
# 2012    10962
# 2011     8998
# Name: sales, dtype: int64

# %% [markdown]
# ### how much sales in africa region after 2013?

# %%
df[(df['year']>2013)& (df['region']=='Africa')]
# Out:
#            order_id order_date  ship_date      segment              state  \
# 33765  AG-2014-2040 2014-01-01 2014-06-01     Consumer              Alger
# 33771   CG-2014-920 2014-01-01 2014-02-01     Consumer           Kinshasa
# 33776  AG-2014-2360 2014-01-01 2014-06-01     Consumer         Mostaganem
# 33784  SU-2014-3390 2014-02-01 2014-06-01     Consumer            Red Sea
# 33786  SU-2014-3390 2014-02-01 2014-06-01     Consumer            Red Sea
# ...             ...        ...        ...          ...                ...
# 51252  OD-2014-9490 2014-12-31 2015-05-01    Corporate  Central Equatoria
# 51253  AO-2014-7730 2014-12-31 2015-04-01     Consumer             Luanda
# 51262  TZ-2014-8350 2014-12-31 2015-03-01     Consumer      Dar Es Salaam
# 51280  TZ-2014-8220 2014-12-31 2015-06-01  Home Office      Dar Es Salaam
# 51286  MO-2014-2560 2014-12-31 2015-05-01     Consumer   Souss-Massa-Draâ
#
#                                 country  market  region        product_id  \
# ...

# %% [markdown]
# ### how many order placed in market of 'US' after 2013?

# %%
df[(df['year']>2013)&(df['market']=='US')]['order_id'].count()
# Out:
# 3319

# %% [markdown]
# ### number of the markets ?

# %%
df['market'].unique()
# Out:
# array(['Africa', 'APAC', 'EMEA', 'EU', 'Canada', 'LATAM', 'US'],
#       dtype=object)

# %% [markdown]
# ### Count of sales in different markets?

# %%
df.groupby('market').sales.count()
# Out:
# market
# APAC      11002
# Africa     4587
# Canada      384
# EMEA       5029
# EU        10000
# LATAM     10294
# US         9994
# Name: sales, dtype: int64

# %%
df.head(2)
# Out:
#         order_id order_date  ship_date   segment            state    country  \
# 0   AG-2011-2040 2011-01-01 2011-06-01  Consumer      Constantine    Algeria
# 1  IN-2011-47883 2011-01-01 2011-08-01  Consumer  New South Wales  Australia
#
#    market   region        product_id         category sub_category  \
# 0  Africa   Africa  OFF-TEN-10000025  Office Supplies      Storage
# 1    APAC  Oceania   OFF-SU-10000618  Office Supplies     Supplies
#
#                product_name sales  quantity  discount   profit  shipping_cost  \
# 0       Tenex Lockers, Blue   408         2       0.0  106.140          35.46
# 1  Acme Trimmer, High Speed   120         3       0.1   36.036           9.72
#
#    year delivery_days
# 0  2011      151 days
# 1  2011      212 days

# %% [markdown]
# ### types of category?

# %%
df['category'].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %% [markdown]
# ### Count of office supplies ?

# %%
df[df['category']=='Office Supplies'].category.count()
# Out:
# 31273

# %% [markdown]
# ### number of furniture sold?

# %%
df[df['category']=='Furniture'].category.count()
# Out:
# 9876

# %%
# number of Technology things sold
df[df['category']=='Technology'].category.count()
# Out:
# 10141

# %%
df['sub_category'].unique()
# Out:
# array(['Storage', 'Supplies', 'Paper', 'Furnishings', 'Machines',
#        'Appliances', 'Copiers', 'Chairs', 'Tables', 'Bookcases', 'Phones',
#        'Accessories', 'Labels', 'Art', 'Envelopes', 'Fasteners',
#        'Binders'], dtype=object)

# %%
# how much Bookcases were sold??
df.groupby('sub_category').sub_category.count()
# Out:
# sub_category
# Accessories    3075
# Appliances     1755
# Art            4883
# Binders        6152
# Bookcases      2411
# Chairs         3434
# Copiers        2223
# Envelopes      2435
# Fasteners      2420
# Furnishings    3170
# Labels         2606
# Machines       1486
# Paper          3538
# Phones         3357
# Storage        5059
# Supplies       2425
# Tables          861
# Name: sub_category, dtype: int64

# %% [markdown]
# ### Three low sales sub_category product

# %%
df.groupby('sub_category').sub_category.count().sort_values(ascending = True).head(3)
# Out:
# sub_category
# Tables         861
# Machines      1486
# Appliances    1755
# Name: sub_category, dtype: int64

# %% [markdown]
# ### Three top sales sub_category products?

# %%
df.groupby('sub_category').sub_category.count().sort_values(ascending = False).head(3)
# Out:
# sub_category
# Binders    6152
# Storage    5059
# Art        4883
# Name: sub_category, dtype: int64

# %% [markdown]
# ### on "Supplies" sub_category product --> how many order placed??

# %%
df[df['sub_category']=='Supplies'].order_id.count()
# Out:
# 2425

# %% [markdown]
# ### Maximum sales How much?

# %%
df.sales.max()
# Out:
# '999'

# %% [markdown]
# ### On which date , which state and which country sales was maximum??

# %%
df[df['sales']==df.sales.max()][['order_date','state','country','sales']]
# Out:
#       order_date       state        country sales
# 5676  2011-09-27    Brittany         France   999
# 7602  2011-11-28       Texas  United States   999
# 8823  2011-12-28  California  United States   999
# 14710 2012-08-24       Texas  United States   999
# 40454 2014-06-28   Guatemala      Guatemala   999

# %%
df.head(2)
# Out:
#         order_id order_date  ship_date   segment            state    country  \
# 0   AG-2011-2040 2011-01-01 2011-06-01  Consumer      Constantine    Algeria
# 1  IN-2011-47883 2011-01-01 2011-08-01  Consumer  New South Wales  Australia
#
#    market   region        product_id         category sub_category  \
# 0  Africa   Africa  OFF-TEN-10000025  Office Supplies      Storage
# 1    APAC  Oceania   OFF-SU-10000618  Office Supplies     Supplies
#
#                product_name sales  quantity  discount   profit  shipping_cost  \
# 0       Tenex Lockers, Blue   408         2       0.0  106.140          35.46
# 1  Acme Trimmer, High Speed   120         3       0.1   36.036           9.72
#
#    year delivery_days
# 0  2011      151 days
# 1  2011      212 days

# %% [markdown]
# ### How many type of segments and count of segments??

# %%
df.groupby('segment').segment.count()
# Out:
# segment
# Consumer       26518
# Corporate      15429
# Home Office     9343
# Name: segment, dtype: int64

# %% [markdown]
# ### total profit earned by Store in dollers?

# %%
'$' + str(df['profit'].sum().round(2))
# Out:
# '$1469034.82'

# %% [markdown]
# ### Total profit earned by store in 2012?

# %%
df[df['year']==2012]['profit'].sum().round(2)
# Out:
# 307415.28

# %%
df.head()
# Out:
#           order_id order_date  ship_date      segment            state  \
# 0     AG-2011-2040 2011-01-01 2011-06-01     Consumer      Constantine
# 1    IN-2011-47883 2011-01-01 2011-08-01     Consumer  New South Wales
# 2     HU-2011-1220 2011-01-01 2011-05-01     Consumer         Budapest
# 3  IT-2011-3647632 2011-01-01 2011-05-01  Home Office        Stockholm
# 4    IN-2011-47883 2011-01-01 2011-08-01     Consumer  New South Wales
#
#      country  market   region        product_id         category sub_category  \
# 0    Algeria  Africa   Africa  OFF-TEN-10000025  Office Supplies      Storage
# 1  Australia    APAC  Oceania   OFF-SU-10000618  Office Supplies     Supplies
# 2    Hungary    EMEA     EMEA  OFF-TEN-10001585  Office Supplies      Storage
# 3     Sweden      EU    North   OFF-PA-10001492  Office Supplies        Paper
# 4  Australia    APAC  Oceania   FUR-FU-10003447        Furniture  Furnishings
#
#                   product_name sales  quantity  discount   profit  \
# ...

# %%
df['sales'] = df['sales'].str.replace(',', '').astype(int)

# %%
df.dtypes
# Out:
# order_id                  object
# order_date        datetime64[ns]
# ship_date         datetime64[ns]
# segment                   object
# state                     object
# country                   object
# market                    object
# region                    object
# product_id                object
# category                  object
# sub_category              object
# product_name              object
# sales                      int32
# quantity                   int64
# discount                 float64
# profit                   float64
# shipping_cost            float64
# year                       int64
# delivery_days    timedelta64[ns]
# dtype: object

# %% [markdown]
# ### Total sales of superstore?

# %%
df['sales'].sum()
# Out:
# 12642905

# %% [markdown]
# ### total sales by year ?

# %%
df.groupby('year').sales.sum().sort_values(ascending = False)
# Out:
# year
# 2014    4300041
# 2013    3405860
# 2012    2677493
# 2011    2259511
# Name: sales, dtype: int32

# %% [markdown]
# ### Avarage sales?

# %%
df['sales'].mean()
# Out:
# 246.49844024176252

# %% [markdown]
# ### which category product sold mostly in 2014 and how much?

# %%
df[df['year']==2014][['category']].groupby('category').category.count().sort_values(ascending= False).head(1)
# Out:
# category
# Office Supplies    10729
# Name: category, dtype: int64

# %%
df.head(2)
# Out:
#         order_id order_date  ship_date   segment            state    country  \
# 0   AG-2011-2040 2011-01-01 2011-06-01  Consumer      Constantine    Algeria
# 1  IN-2011-47883 2011-01-01 2011-08-01  Consumer  New South Wales  Australia
#
#    market   region        product_id         category sub_category  \
# 0  Africa   Africa  OFF-TEN-10000025  Office Supplies      Storage
# 1    APAC  Oceania   OFF-SU-10000618  Office Supplies     Supplies
#
#                product_name  sales  quantity  discount   profit  \
# 0       Tenex Lockers, Blue    408         2       0.0  106.140
# 1  Acme Trimmer, High Speed    120         3       0.1   36.036
#
#    shipping_cost  year delivery_days
# 0          35.46  2011      151 days
# 1           9.72  2011      212 days

# %%
df['sales'].describe().astype(int)
# Out:
# count    51290
# mean       246
# std        487
# min          0
# 25%         31
# 50%         85
# 75%        251
# max      22638
# Name: sales, dtype: int32

# %% [markdown]
# #### How much % sales commited in 2011 from total sales?

# %%
((df[df['year']==2011]['sales'].sum())/(df['sales'].sum())*100).round(2)
# Out:
# 17.87

# %% [markdown]
# #### How much % sales commited in 2012 from total sales?

# %%
((df[df['year']==2012]['sales'].sum())/(df['sales'].sum())*100).round(2)
# Out:
# 21.18

# %% [markdown]
# #### How much % sales commited in 2013 from total sales???

# %%
((df[df['year']==2013]['sales'].sum())/(df['sales'].sum())*100).round(2)
# Out:
# 26.94

# %% [markdown]
# #### How much % sales commited in 2014 from total sales?

# %%
((df[df['year']==2014]['sales'].sum())/(df['sales'].sum())*100).round(2)
# Out:
# 34.01

# %%
df['total_sales']=df['sales']* df['quantity']

# %%
df.head()
# Out:
#           order_id order_date  ship_date      segment            state  \
# 0     AG-2011-2040 2011-01-01 2011-06-01     Consumer      Constantine
# 1    IN-2011-47883 2011-01-01 2011-08-01     Consumer  New South Wales
# 2     HU-2011-1220 2011-01-01 2011-05-01     Consumer         Budapest
# 3  IT-2011-3647632 2011-01-01 2011-05-01  Home Office        Stockholm
# 4    IN-2011-47883 2011-01-01 2011-08-01     Consumer  New South Wales
#
#      country  market   region        product_id         category sub_category  \
# 0    Algeria  Africa   Africa  OFF-TEN-10000025  Office Supplies      Storage
# 1  Australia    APAC  Oceania   OFF-SU-10000618  Office Supplies     Supplies
# 2    Hungary    EMEA     EMEA  OFF-TEN-10001585  Office Supplies      Storage
# 3     Sweden      EU    North   OFF-PA-10001492  Office Supplies        Paper
# 4  Australia    APAC  Oceania   FUR-FU-10003447        Furniture  Furnishings
#
#                   product_name  sales  quantity  discount   profit  \
# ...

# %% [markdown]
# ### Total Sales with quantity?

# %%
df['total_sales'].sum()
# Out:
# 61822900

# %% [markdown]
# ### how much profit earned by superstore with respect to year?

# %%
df.groupby('year').profit.sum().sort_values(ascending= False)
# Out:
# year
# 2014    504165.97046
# 2013    408512.76018
# 2012    307415.27910
# 2011    248940.81154
# Name: profit, dtype: float64

# %% [markdown]
# ### Maximum Profit?

# %%
df['profit'].max()
# Out:
# 8399.976

# %% [markdown]
# ### On which category , segment, state ,sales and quantity where profit wasgiven maximum ?

# %%
df[df['profit']==df['profit'].max()][['segment','state','country','category','sales','quantity','year']]
# Out:
#          segment    state        country    category  sales  quantity  year
# 29530  Corporate  Indiana  United States  Technology  17500         5  2013

# %% [markdown]
# ##### to get better sales in Technology category products should be increase some discount

# %%
df[df['sales']==df['sales'].max()]
# Out:
#             order_id order_date  ship_date      segment    state  \
# 1103  CA-2011-145317 2011-03-18 2011-03-23  Home Office  Florida
#
#             country market region       product_id    category sub_category  \
# 1103  United States     US  South  TEC-MA-10002412  Technology     Machines
#
#                                            product_name  sales  quantity  \
# 1103  Cisco TelePresence System EX90 Videoconferenci...  22638         6
#
#       discount     profit  shipping_cost  year delivery_days  total_sales
# 1103       0.5 -1811.0784          24.29  2011        5 days       135828

# %% [markdown]
# #### On this order superstore got -1811.0784 loss in 2011.
